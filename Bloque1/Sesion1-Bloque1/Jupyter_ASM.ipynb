# %% [markdown]
# # Alejandro Sánchez Monzón

# %%
a = 1
b = False
c = "big data"
d = 6.78

# %% [markdown]
# Imprimiendo el valor y tipo de la variable "a":

# %%
print(a)
type(a)
# Out:
# 1
# int

# %% [markdown]
# Imprimiendo el valor y tipo de la variable "b":

# %%
print(b)
type(b)
# Out:
# False
# bool

# %% [markdown]
# Imprimiendo el valor y tipo de la variable "c":

# %%
print(c)
type(c)
# Out:
# big data
# str

# %% [markdown]
# Imprimiendo el valor y tipo de la variable "d":

# %%
print(d)
type(d)
# Out:
# 6.78
# float

# %% [markdown]
# ---

# %% [markdown]
# # Instalación de librería "shap":

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Anotación**
#
#
# Inicialmente he dudado si el comando correcto era `conda install -c conda-forge shap` o `pip install shap` (desde dentro de python).
#
# He buscado información en internet y me indicada que el comando conda era el más correcto para evitar conflictos de dependencias a futuro.
# Finalmente, me he decantado por el comando de conda porque, aparentemente, es el que recomienda la propia página de Anaconda.
