# %% [markdown]
# # Alejandro Sánchez Monzón

# %%
print("Primera tarea de Python.")
# Out:
# Primera tarea de Python.

# %% [markdown]
# # Comando "conda info"

# %% [markdown]
# active environment : base
#     active env location : C:\Users\aleja\anaconda3
#             shell level : 1
#        user config file : C:\Users\aleja\.condarc
#  populated config files : C:\Users\aleja\.condarc
#           conda version : 23.7.3
#     conda-build version : 3.26.0
#          python version : 3.11.4.final.0
#        virtual packages : __archspec=1=x86_64
#                           __cuda=12.0=0
#                           __win=0=0
#        base environment : C:\Users\aleja\anaconda3  (writable)
#       conda av data dir : C:\Users\aleja\anaconda3\etc\conda
#   conda av metadata url : None
#            channel URLs : https://repo.anaconda.com/pkgs/main/win-64
#                           https://repo.anaconda.com/pkgs/main/noarch
#                           https://repo.anaconda.com/pkgs/r/win-64
#                           https://repo.anaconda.com/pkgs/r/noarch
#                           https://repo.anaconda.com/pkgs/msys2/win-64
#                           https://repo.anaconda.com/pkgs/msys2/noarch
#           package cache : C:\Users\aleja\anaconda3\pkgs
#                           C:\Users\aleja\.conda\pkgs
#                           C:\Users\aleja\AppData\Local\conda\conda\pkgs
#        envs directories : C:\Users\aleja\anaconda3\envs
#                           C:\Users\aleja\.conda\envs
#                           C:\Users\aleja\AppData\Local\conda\conda\envs
#                platform : win-64
#              user-agent : conda/23.7.3 requests/2.31.0 CPython/3.11.4 Windows/10 Windows/10.0.22621
#           administrator : False
#              netrc file : None
#            offline mode : False

# %% [markdown]
# ![image.png](attachment:image.png)
